# %% [markdown]
# # **XGboost**
#
# ## XGBoost + k-fold CV + Feature Importance
#
#
# XGboost short for Extreme gradient boosting model is one of the most used model which won the kaggle compititions
#
# So in this notebook we will learn about xgboost in depth from intuation to implementation
#
# - XGboost is nothing but more optimised gradient boosted trees with regularization and much more robustness and performance

# %% [markdown]
# ## Evoluation of Trees based models
#  Decision Trees -> Bagging -> Random forest -> Boosting -> Gradient boosting -> Xgboost

# %% [markdown]
# # Core Concepts of XGboosts
#
# ## **The Idea of ensemble** : (Weak trees -> Strong Decisions )
# - **Concepts** : Why use different trees when we can use the weak trees to make a decision based on the weak trees
# - **Intuition** : It is like each succeeding trees corrects the errors caused by previous trees / models
